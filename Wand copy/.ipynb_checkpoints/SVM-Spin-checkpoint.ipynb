# %%
import numpy as np
import pandas as pd

from sklearn.datasets import make_blobs, make_circles
from sklearn.svm import SVC

import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d
# %matplotlib inline
import seaborn as sns; sns.set()

# %% [markdown]
#  # [gyro_x, gyro_y, gyro_z, accel_x, accel_y, accel_z]

# %%
wave_data = []
wave_data.append(pd.read_csv('./swipe/data_1_np.csv'))
wave_data[0]
# Out:
#      8.843993000000000393e+01  5.804442999999999842e+01  \
# 0                    93.81103                 40.466300
# 1                   113.34230                 -0.122070
# 2                    67.93213                -28.808590
# 3                   -53.28369                  1.831055
# 4                     9.94873                 84.350580
# ..                        ...                       ...
# 282                 324.40180                 53.100580
# 283                -204.34570                 54.809570
# 284                  22.82715                 71.716310
# 285                 106.56740                 96.984850
# 286                  65.97900                 47.363280
#
#      1.763916000000000039e+01  3.769530999999999854e-01  \
# 0                   -254.8218                  0.853394
# 1                   -458.4350                  2.173828
# 2                   -531.1279                  3.060425
# 3                   -526.0010                  2.934937
# 4                   -395.0805                  2.199829
# ..                        ...                       ...
# 282                  512.1460                  0.669189
# 283                 -291.8701                  0.810181
# 284                 -377.0141                  1.084595
# 285                 -358.4594                  1.097900
# 286                 -406.0058                  1.561279
#
#      3.998778999999999861e+00  1.575561999999999907e+00
# 0                    3.986084                  0.567749
# 1                    1.894775                  1.006958
# 2                    0.510498                  1.711060
# 3                   -0.526733                  2.237793
# 4                   -1.274780                  1.973633
# ..                        ...                       ...
# 282                  3.998779                  3.113525
# 283                  3.913330                  0.131104
# 284                  0.510864                  1.482178
# 285                  0.223877                  1.033813
# 286                 -0.148560                  1.138428
#
# [287 rows x 6 columns]

# %%
gyro_x = wave_data[0].iloc[:, 0].values
gyro_y = wave_data[0].iloc[:, 1].values
gyro_z = wave_data[0].iloc[:, 2].values
accel_x = wave_data[0].iloc[:, 3].values
accel_y = wave_data[0].iloc[:, 4].values
accel_z = wave_data[0].iloc[:, 5].values


def check_data_pattern(d):
    x = np.linspace(0, len(d), len(d))
    y = d

    plt.plot(x, y, 'o', color='red')

# %%
check_data_pattern(gyro_x)

# %%
check_data_pattern(gyro_y)

# %%
check_data_pattern(gyro_z)

# %%
check_data_pattern(accel_x)

# %%
check_data_pattern(accel_y)

# %%
check_data_pattern(accel_z)

# %%
import sklearn
import numpy as np
from sklearn.neighbors import KNeighborsClassifier


def train_model(vertical_swipe, horizontal_swish):
     vertical_swipe   = np.asarray(vertical_swipe)
     horizontal_swish = np.asarray(horizontal_swish)
     X = np.append(vertical_swipe, horizontal_swish, axis=0)
     y = np.append(np.zeros(vertical_swipe.shape[0]), np.ones(horizontal_swish.shape[0]))
     model = KNeighborsClassifier(n_neighbors=15)
     model.fit(X,y)
     
     return model; 

def predict_model(model,data):
     data = np.array(data)
     if np.any(np.isnan(data)) or np.any(np.isinf(data)):
          return 0
     return model.predict(data.reshape(1,-1))[0]

def run_training_and_prediction(vertical_swipe, horizontal_swish, data):
     model = train_model(vertical_swipe, horizontal_swish)
     return predict_model(model, data)
